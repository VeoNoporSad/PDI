# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [10,5]

img_cancerbgr = cv2.imread(r"C:/Universidad/QuintoSemestre/PDI/Imagenes/dd6.jpg") #Imagen Trabajadora
img_cancerrgb = plt.imread(r"C:/Universidad/QuintoSemestre/PDI/Imagenes/dd6.jpg")

imagen = cv2.cvtColor(img_cancerbgr,cv2.COLOR_BGR2RGB)
plt.imshow(imagen)

# %%
plt.imshow(imagen[50:60,20:35,:])
plt.show()

# %%
#plt.imshow(imagen[50:60,20:35,:])

#plt.show()

celula_cancer = imagen[50:60,20:35,:]
plt.imsave("ImagenCelularCancer.jpg", celula_cancer)
celula = plt.imread("ImagenCelularCancer.jpg")
color = ('r', 'g', 'b')
for canal, col in enumerate(color):
    histograma = cv2.calcHist([celula*255],[canal],None,[256], [0,256])
    plt.title("Histograma")
    plt.plot(histograma, color = col)
    plt.xlim([0,256])
plt.show()

# %%
r_celula = celula[:,:,0]*255
g_celula = celula[:,:,1]*255
b_celula = celula[:,:,2]*255

r_celula = r_celula>200
g_celula = g_celula>200
b_celula = b_celula>200

img_fin = np.array(r_celula * g_celula * b_celula * 255)
plt.imshow(img_fin)
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def solarizar(image,umbral):
    img_solarizada = np.where(image<umbral,image,255-image)
    return img_solarizada

def posterizar(image,nivel):
    f_nvl=255/nivel
    img_poster=np.round(image/f_nvl)*f_nvl
    return img_poster.astype(np.uint8)




img = cv2.imread(r"C:/Universidad/QuintoSemestre/PDI/Imagenes/dd6.jpg")
img_gris = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

##############################
umbral = 127
img_sol = solarizar(img_gris, umbral)
##############################
nivel = 4
img_posterizada = posterizar(img_gris, nivel)
##############################
plt.subplot(3,1,1)
plt.imshow(img_gris, cmap='gray')
plt.title("Original")

plt.subplot(3,1,2)
plt.imshow(img_sol, cmap="gray")
plt.title("Solarizada")

plt.subplot(3,1,3)
plt.imshow(img_posterizada, cmap='gray')
plt.title("Posterizada")

plt.tight_layout()
plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
vec = [cv.COLORMAP_AUTUMN,
  cv.COLORMAP_BONE,
  cv.COLORMAP_JET,
  cv.COLORMAP_WINTER,
  cv.COLORMAP_RAINBOW,
  cv.COLORMAP_OCEAN,
  cv.COLORMAP_SUMMER,
  cv.COLORMAP_SPRING,
  cv.COLORMAP_COOL,
  cv.COLORMAP_HSV,
  cv.COLORMAP_PINK,
  cv.COLORMAP_HOT,
  cv.COLORMAP_PARULA,
  cv.COLORMAP_MAGMA,
  cv.COLORMAP_INFERNO,
  cv.COLORMAP_PLASMA,
  cv.COLORMAP_VIRIDIS,
  cv.COLORMAP_CIVIDIS,
  cv.COLORMAP_TWILIGHT,
  cv.COLORMAP_TWILIGHT_SHIFTED,
  cv.COLORMAP_TURBO,
  cv.COLORMAP_DEEPGREEN]

vecname = ["original",
  "COLORMAP_AUTUMN",
  "COLORMAP_BONE",
  "OLORMAP_JET",
  "COLORMAP_WINTER",
  "COLORMAP_RAINBOW",
  "COLORMAP_OCEAN",
  "COLORMAP_SUMMER",
  "COLORMAP_SPRING",
  "COLORMAP_COOL",
  "COLORMAP_HSV",
  "COLORMAP_PINK",
  "COLORMAP_HOT",
  "COLORMAP_PARULA",
  "OLORMAP_MAGMA",
  "COLORMAP_INFERNO",
  "COLORMAP_PLASMA",
  "COLORMAP_VIRIDIS",
  "COLORMAP_CIVIDIS",
  "COLORMAP_TWILIGHT",
  "COLORMAP_TWILIGHT_SHIFTED",
  "COLORMAP_TURBO",
  "COLORMAP_DEEPGREEN"]
a = 1
plt.figure(figsize=(10, 10))
im = cv.imread(r"C:/Universidad/QuintoSemestre/PDI/Imagenes/dd5.jpg", cv.IMREAD_GRAYSCALE)
imgp = cv.cvtColor(im, cv.COLOR_BGR2RGB)
for i in range(0, len(vec)):


    imC = cv.applyColorMap(im, vec[i])

    if (i == 0):
        plt.subplot(6,4,1)
        plt.imshow(imgp)
        plt.title("Original")
    plt.subplot(6,4,a + 1)
    plt.imshow(imC)
    plt.title(vecname[i])
    a = a + 1
plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=[10,5]
tamanio_img = 100
R = np.ones((tamanio_img, tamanio_img))*255
G = np.ones((tamanio_img, tamanio_img))*128
B = np.ones((tamanio_img, tamanio_img))*0

imagen = np.dstack((R, G, B))
imagen = np.array(imagen, dtype=int)
plt.figure()
plt.imshow(imagen)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread(r"C:/Universidad/QuintoSemestre/PDI/Imagenes/dd5.jpg", cv2.IMREAD_GRAYSCALE)
img_color = cv2.imread(r"C:/Universidad/QuintoSemestre/PDI/Imagenes/dd5.jpg", cv2.COLOR_BGR2RGB)
negativo = 255 - img
negativo_color = 255 - img_color

plt.subplot(2,2,1)
plt.imshow(img)
plt.title("Original")

plt.subplot(2,2,2)
plt.imshow(negativo)
plt.title("Negativo")

plt.subplot(2,2,3)
plt.imshow(img_color)
plt.title("Imagen Color")

plt.subplot(2,2,4)
plt.imshow(negativo_color)
plt.title("Imagen Color")



plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def contraste(imagen, a=1.0, b=0):
    img_nueva = np.clip(a * imagen + b, 0, 255).astype(np.uint8)
    return img_nueva

img = cv2.imread(r"C:/Universidad/QuintoSemestre/PDI/Imagenes/dd3.jpg", cv2.IMREAD_GRAYSCALE)
img_contraste = contraste(img,2.0,0)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title('Imagen Original')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_contraste, cmap='gray')
plt.title('Imagen con Contraste')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def contraste_color(imagen, a=1.0, b=0):
    img_nueva = cv2.convertScaleAbs(img, alpha= a, beta= b)
    return img_nueva

imagen = cv2.imread(r"C:/Universidad/QuintoSemestre/PDI/Imagenes/dd3.jpg")
blue, red, green = cv2.split(imagen)

contraste_blue = contraste_color(blue, 1.2,1)
contraste_red = contraste_color(red, 1.2,1)
contraste_green = contraste_color(green, 1.2,1)

fin_img = cv2.merge((contraste_blue, contraste_red, contraste_green))


plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.imshow(imagen, cmap='gray')
plt.title('Imagen Original')
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(fin_img, cmap='gray')
plt.title('Imagen con Contraste')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Cargar la imagen
imagen = cv2.imread(r"C:/Universidad/QuintoSemestre/PDI/Imagenes/dd3.jpg")

# Convertir la imagen a escala de grises
imagen_gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

# Calcular la luminosidad de cada píxel
luminosidad = np.mean(imagen_gris, axis=2)

# Mostrar la imagen original
plt.figure(figsize=(10, 6))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))
plt.title('Imagen Original')

# Mostrar la imagen de luminosidad
plt.subplot(1, 2, 2)
plt.imshow(luminosidad, cmap='gray')
plt.title('Imagen de Luminosidad')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[19], line 12
#       9 imagen_gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
#      11 # Calcular la luminosidad de cada píxel
# ---> 12 luminosidad = np.mean(imagen_gris, axis=2)
#      14 # Mostrar la imagen original
#      15 plt.figure(figsize=(10, 6))
#
# File c:\Users\Italo\.conda\envs\NuevoEntorno\Lib\site-packages\numpy\core\fromnumeric.py:3504, in mean(a, axis, dtype, out, keepdims, where)
#    3501     else:
#    3502         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3504 return _methods._mean(a, axis=axis, dtype=dtype,
#    3505                       out=out, **kwargs)
#
# File c:\Users\Italo\.conda\envs\NuevoEntorno\Lib\site-packages\numpy\core\_methods.py:106, in _mean(a, axis, dtype, out, keepdims, where)
#     102 arr = asanyarray(a)
#     104 is_float16_result = False
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread(r"C:/Universidad/QuintoSemestre/PDI/Imagenes/d7.jpeg", cv2.IMREAD_GRAYSCALE)

histograma, _ = np.histogram(img.flatten(), 256, [0, 256])
funcion_dist = histograma.cumsum()
hst_normalizado = funcion_dist * histograma.max() / funcion_dist.max()
img_ecualizada = cv2.equalizeHist(img)

plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.imshow(img)
plt.title('Imagen Original')

# Mostrar el histograma
plt.subplot(2, 2, 2)
plt.plot(histograma)
plt.title('Histograma')

plt.subplot(2, 2, 3)
plt.plot(hst_normalizado)
plt.title('Histograma Normalizado')

plt.subplot(2, 2, 4)
plt.imshow(img_ecualizada)
plt.title('Imagen Ecualizada')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread(r"C:/Universidad/QuintoSemestre/PDI/Imagenes/d7.jpeg")
img_gris = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # Convertir a escala de grises

clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
img_nueva = clahe.apply(img_gris)

histograma, _ = np.histogram(img_nueva.flatten(), 256, [0, 256])
funcion_dist = histograma.cumsum()
hst_normalizado = funcion_dist * histograma.max() / funcion_dist.max()
img_ecualizada = cv2.equalizeHist(img_nueva)

plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Imagen Original')

# Mostrar el histograma
plt.subplot(2, 2, 2)
plt.plot(histograma)
plt.title('Histograma')

plt.subplot(2, 2, 3)
plt.plot(hst_normalizado)
plt.title('Histograma Normalizado')

plt.subplot(2, 2, 4)
plt.imshow(img_ecualizada, cmap='gray')
plt.title('Imagen Ecualizada')

plt.show()

# %%
import cv2 as cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread(r'C:\Universidad\QuintoSemestre\PDI\Imagenes\d7.jpeg', 1)
clahe =  cv.createCLAHE(clipLimit= 2.0, tileGridSize= (8, 8))

img_gris = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  #Escala grises
img_nueva = clahe.apply(img_gris) #Aplic clahe
histograma = np.histogram(img, 256, [0, 256]) #Creo histograma




red, green, blue = cv.split(img)

contraste_blue = clahe.apply(red) 
contraste_red =  clahe.apply(green)
contraste_green = clahe.apply(blue)
finImgClahe = cv.merge((contraste_red, contraste_green, contraste_blue)) #Junto los 3 contrastes
histograma_clahe = np.histogram(img_nueva, 256, [0, 256])


contraste_blue = cv.equalizeHist(red)
contraste_red =  cv.equalizeHist(green)
contraste_green = cv.equalizeHist(blue)
finImgEcua = cv.merge((contraste_red, contraste_green, contraste_blue)) #Junto los 3 contrastes
histograma_ecua = np.histogram(img_nueva, 256, [0, 256])

plt.figure(figsize=(10, 5))

plt.subplot(3, 2, 1)
plt.title('Original')
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))


plt.subplot(3, 2, 2)
plt.plot(histograma[0], color='purple')
plt.title('Histograma')
plt.xlabel('intensidad_pixel')
plt.ylabel('frecuencia_pixel')


plt.subplot(3, 2, 3)
plt.title('Imagen Ecualizada Color')
plt.imshow(cv.cvtColor(finImgEcua, cv.COLOR_BGR2RGB))

plt.subplot(3, 2, 4)
plt.plot(histograma_ecua[0], color='green')
plt.title('Histograma Ecualizado Color')
plt.xlabel('intensidad_pixel')
plt.ylabel('frecuencia_pixel')


plt.subplot(3, 2, 5)
plt.title('Imagen Ecualizada Clahe Color')
plt.imshow(cv.cvtColor(finImgClahe, cv.COLOR_BGR2RGB))


plt.subplot(3, 2, 6)
plt.plot(histograma_clahe[0], color='orange')
plt.title('Histograma Ecualizado Clahe Color')
plt.xlabel('intensidad_pixel')
plt.ylabel('frecuencia_pixel')

plt.tight_layout()
plt.show()
