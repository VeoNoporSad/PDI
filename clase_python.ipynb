# %%
limitee = input("Ingrese el límite: ")
limite = int(limitee)
a = 0
b = 1  
c = 0
var = 0

while True:
    if var <= limite:
        if c != 0:
            print(c)
    else:
        break
    c = a + b
    a = b
    b = c
    var += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 limitee = input("Ingrese el límite: ")
#       2 limite = int(limitee)
#       3 a = 0
#
# File c:\Users\Italo\.conda\envs\NuevoEntorno\Lib\site-packages\ipykernel\kernelbase.py:1270, in Kernel.raw_input(self, prompt)
#    1268     msg = "raw_input was called, but this frontend does not support input requests."
#    1269     raise StdinNotImplementedError(msg)
# -> 1270 return self._input_request(
#    1271     str(prompt),
#    1272     self._parent_ident["shell"],
#    1273     self.get_parent("shell"),
#    1274     password=False,
#    1275 )
#
# File c:\Users\Italo\.conda\envs\NuevoEntorno\Lib\site-packages\ipykernel\kernelbase.py:1313, in Kernel._input_request(self, prompt, ident, parent, password)
#    1310 except KeyboardInterrupt:
# ...

# %%
lado = input("Ingrese el lado del cuadrado")
ladoo = float(lado)
print("El area del cuadrado es: ")
print(ladoo * ladoo)
print("El Perimetro del cuadrado es: ")
print(4 * ladoo)
# Out:
# El area del cuadrado es:
# 25
# El Perimetro del cuadrado es:
# 20

# %%
palabra = input("Ingrese la palabra")
cantidad = int(input("Ingrese la cantidad de repeticiones"))
for numero in range(1, cantidad + 1):
        print(palabra)
# Out:
# adios
# adios
# adios
# adios
# adios

# %%
palabra = input("Ingrese una palabra")
longitud = len(palabra)
for numero in range(0, longitud):
        if palabra[numero] == "a":
            SoloVocales = SoloVocales + "a"
        if palabra[numero] == "i":
            SoloVocales = SoloVocales + "i"
        if palabra[numero] == "o":
            SoloVocales = SoloVocales +"o"
        if palabra[numero] == "u":
            SoloVocales = SoloVocales + "u"
        else:
            SoloVocales = SoloVocales + palabra[numero]

mayus = SoloVocales.upper()
print(mayus)
SoloVocales = ""
# Out:
#   Cell In[15], line 6
#     else if
#     ^
# SyntaxError: invalid syntax

# %%
import re
a = 0
palindromo = ""
palindromo2 = ""
cadenaespacios = ""
cadena = input("Ingrese una palabra")
longitud = len(cadena)
pal = longitud
SinEspacios= re.sub(r"\s+", "", cadena)
print(SinEspacios)
longitud2 = len(SinEspacios)
pal2 = longitud2
a = 0
b = 0
while (b < longitud2):
    palindromo2 = palindromo2 + SinEspacios[pal2 - 1]
    pal2 = pal2 - 1
    b = b + 1
print(palindromo2)

if (palindromo2 == SinEspacios):
    print("Palindroma")
else:
    print("No es palindroma")
# Out:
# anitalavalatina
# anitalavalatina
# Palindroma

# %%
MasAlto = 0
cantidad = input("Ingrese la cantidad de numeros que desee")
cantidadentero = int(cantidad)
for numero in range(0, cantidadentero):
    num = int(input("Numero "))
    if (num > MasAlto):
        MasAlto = num

print("El numero mas alto es: ")
print(MasAlto)
# Out:
# El numero mas alto es:
# 30

# %%
es = True
primo = int(input())
for numero in range (2, primo):
    if (primo % numero == 0):
        es = False
        break
    else:
        es = True
if (es):
    print("Si es Primo")
else:
    print("No es primo")
# Out:
# Si es Primo

# %%
from collections import Counter
lista = []
veces = 0
for numero in range(1, 8):
    num = input("Ingrese un num")
    lista.append(num)
a=Counter(lista).most_common()[0][0]
for numero in range(1, 8):
    if (a == lista[numero - 1]):
        veces = veces + 1
print("Numero más repetido")
print(a)
print("Con una cantidad de")
print(veces)
# Out:
# Numero más repetido
# 2
# Con una cantidad de
# 3

# %%
fact = int(input("Ingrese un num"))
factorial = 1
for numero in range(1, fact + 1):
    factorial = factorial * numero
print(factorial)
# Out:
# 120

# %%
from PIL import Image
from matplotlib import pyplot as plt
from collections import Counter
from scipy import ndimage as ndi
from skimage import feature
import scipy.misc
import numpy as np
import statistics
import random
import scipy
import time
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
from PIL import Image
from matplotlib import pyplot as plt
from collections import Courter
from scipy import ndimage as ndi
from skimage import feature
import scipy.misc
import numpy as np
import statistics
import random
import scipy
import time
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
from PIL import Image

def open_img(img):
    route = (r"C:/Universidad/QuintoSemestre/PDI/Imagenes/" + img)
    img = Image.open(route)
    img.show()

open_img("dd.jpg")

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %matplotlib inline

plt.rcParams['figure.figsize'] = [10,5]

# %%
img = cv2.imread(r"C:/Universidad/QuintoSemestre/PDI/Imagenes/dd.jpg")
print('size : ', img.shape)
# Out:
# size :  (1600, 900, 3)

# %%
plt.imshow(img)
plt.show()
